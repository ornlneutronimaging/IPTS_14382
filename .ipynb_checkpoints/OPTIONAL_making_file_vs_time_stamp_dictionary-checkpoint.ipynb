# %% [markdown]
# ## Explanations
#
# This notebook will create a python dictionary of the file_name vs time_stamp
#
# ```
# {'Image000_00000.fits': {'day': '3',
#                          'hours': {'hours': '06',
#                                    'minutes': '29',
#                                    'seconds': '50'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image001_00000.fits': {'day': '3',
#                          'hours': {'hours': '06',
#                                    'minutes': '36',
#                                    'seconds': '42'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#                          ...
# }
# ```

# %% [markdown]
# ## Import

# %%
verbose = True

import time
import os
import glob
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib notebook

from ipywidgets import widgets
from IPython.display import display

import gui_widgets
import config_handler
import time_utility
import file_handler

# %%
# %gui qt

# %% [markdown]
# ## Select working data set

# %%
root_folder = config_handler.load_config(key = 'root_folder', \
                                         default_value = '/Volumes/my_book_thunderbolt_duo/IPTS/IPTS_14832/')
data_dir = gui_widgets.gui_dname(dir = root_folder)

config_handler.save_config(key='data_dir', value=data_dir)
config_handler.save_config(key='root_folder', value=root_folder)

# We are only keeping all the first file of each image
# list all *.fits file from data_dir
list_fname = glob.glob(data_dir + '/*0000.fits')

number_of_files = len(list_fname)
if verbose:
    pprint("folder requested: %s" %data_dir)
    pprint("Number of images: %d" %number_of_files)

if verbose:
    pprint(list_fname[0:10])
# Out:
# 'folder requested: /Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015'
# 'Number of images: 51'
# ['/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image000_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image001_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image002_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image003_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image004_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image005_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image006_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image007_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image008_00000.fits',
#  '/Volumes/LaCie/Data_Sebastien/Sebastien_raw_September_2015/Image009_00000.fits']

# %% [markdown]
# ## Retrieving time stamp (when the file was created)

# %%
w = widgets.IntProgress()
w.max = number_of_files

display(w)

file_time_dictionary = {}
list_short_fname = []
for index, _file in enumerate(list_fname):
    date_time_stamp = time.ctime(os.path.getmtime(_file))
    [file_name, time_metadata] = time_utility.format_time_stamp(file_name = _file,
                                                      time_stamp = date_time_stamp)
    file_time_dictionary[file_name] = time_metadata
    list_short_fname.append(file_name)
#    print("%s -> %s" %(_file, date_time_stamp))
    
    w.value = index+1

w.visible = False

if verbose:
    pprint("Infos about first image:")
    pprint(file_time_dictionary[list_short_fname[0]])
    print()
    pprint("Infos about last image:")
    pprint(file_time_dictionary[list_short_fname[-1]])
# Out:
# 'Infos about first image:'
# {'day': '3',
#  'hours': {'hours': '06', 'minutes': '29', 'seconds': '50'},
#  'month': 'Sep',
#  'week_day': 'Thu',
#  'year': '2015'}
#
# 'Infos about last image:'
# {'day': '3',
#  'hours': {'hours': '13', 'minutes': '07', 'seconds': '38'},
#  'month': 'Sep',
#  'week_day': 'Thu',
#  'year': '2015'}

# %%
pprint(file_time_dictionary)
# Out:
# {'Image000_00000.fits': {'day': '3',
#                          'hours': {'hours': '06',
#                                    'minutes': '29',
#                                    'seconds': '50'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image001_00000.fits': {'day': '3',
#                          'hours': {'hours': '06',
#                                    'minutes': '36',
#                                    'seconds': '42'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image002_00000.fits': {'day': '3',
#                          'hours': {'hours': '06',
#                                    'minutes': '43',
#                                    'seconds': '30'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image003_00000.fits': {'day': '3',
#                          'hours': {'hours': '06',
#                                    'minutes': '50',
#                                    'seconds': '24'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image004_00000.fits': {'day': '3',
#                          'hours': {'hours': '06',
#                                    'minutes': '57',
#                                    'seconds': '16'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image005_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '04',
#                                    'seconds': '14'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image006_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '11',
#                                    'seconds': '04'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image007_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '17',
#                                    'seconds': '58'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image008_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '24',
#                                    'seconds': '50'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image009_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '31',
#                                    'seconds': '50'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image010_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '38',
#                                    'seconds': '42'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image011_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '45',
#                                    'seconds': '38'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image012_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '52',
#                                    'seconds': '34'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image013_00000.fits': {'day': '3',
#                          'hours': {'hours': '07',
#                                    'minutes': '59',
#                                    'seconds': '34'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image014_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '06',
#                                    'seconds': '20'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image015_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '13',
#                                    'seconds': '26'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image016_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '20',
#                                    'seconds': '10'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image017_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '27',
#                                    'seconds': '04'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image018_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '33',
#                                    'seconds': '52'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image019_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '40',
#                                    'seconds': '56'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image020_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '47',
#                                    'seconds': '34'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image021_00000.fits': {'day': '3',
#                          'hours': {'hours': '08',
#                                    'minutes': '54',
#                                    'seconds': '24'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image022_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '01',
#                                    'seconds': '10'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image023_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '08',
#                                    'seconds': '16'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image024_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '15',
#                                    'seconds': '26'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image025_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '22',
#                                    'seconds': '32'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image026_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '28',
#                                    'seconds': '50'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image027_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '35',
#                                    'seconds': '52'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image028_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '42',
#                                    'seconds': '58'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image029_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '50',
#                                    'seconds': '00'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image030_00000.fits': {'day': '3',
#                          'hours': {'hours': '09',
#                                    'minutes': '57',
#                                    'seconds': '08'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image031_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '04',
#                                    'seconds': '12'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image032_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '10',
#                                    'seconds': '48'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image033_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '17',
#                                    'seconds': '52'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image034_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '25',
#                                    'seconds': '10'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image035_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '31',
#                                    'seconds': '20'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image036_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '38',
#                                    'seconds': '14'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image037_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '45',
#                                    'seconds': '20'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image038_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '52',
#                                    'seconds': '24'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image039_00000.fits': {'day': '3',
#                          'hours': {'hours': '10',
#                                    'minutes': '59',
#                                    'seconds': '26'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image040_00000.fits': {'day': '3',
#                          'hours': {'hours': '11',
#                                    'minutes': '06',
#                                    'seconds': '34'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image041_00000.fits': {'day': '3',
#                          'hours': {'hours': '11',
#                                    'minutes': '13',
#                                    'seconds': '06'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image042_00000.fits': {'day': '3',
#                          'hours': {'hours': '11',
#                                    'minutes': '27',
#                                    'seconds': '56'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image043_00000.fits': {'day': '3',
#                          'hours': {'hours': '11',
#                                    'minutes': '41',
#                                    'seconds': '18'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image044_00000.fits': {'day': '3',
#                          'hours': {'hours': '11',
#                                    'minutes': '54',
#                                    'seconds': '58'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image045_00000.fits': {'day': '3',
#                          'hours': {'hours': '12',
#                                    'minutes': '08',
#                                    'seconds': '44'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image046_00000.fits': {'day': '3',
#                          'hours': {'hours': '12',
#                                    'minutes': '22',
#                                    'seconds': '32'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image047_00000.fits': {'day': '3',
#                          'hours': {'hours': '12',
#                                    'minutes': '36',
#                                    'seconds': '28'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image048_00000.fits': {'day': '3',
#                          'hours': {'hours': '12',
#                                    'minutes': '50',
#                                    'seconds': '12'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image049_00000.fits': {'day': '3',
#                          'hours': {'hours': '13',
#                                    'minutes': '04',
#                                    'seconds': '12'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'},
#  'Image050_00000.fits': {'day': '3',
#                          'hours': {'hours': '13',
#                                    'minutes': '07',
#                                    'seconds': '38'},
#                          'month': 'Sep',
#                          'week_day': 'Thu',
#                          'year': '2015'}}

# %% [markdown]
# ### output the dictionary using pickle

# %%
base_file_name = data_dir.split('/')[-1]
suffix = '_time_dictionary.dat'

output_file = file_handler.save_file(folder = root_folder,
                                    base_file_name = base_file_name, 
                                    suffix = suffix,
                                    dictionary = file_time_dictionary)

if verbose:
    print("Creating file {}".format(output_file))
# Out:
# Creating file /Volumes/my_book_thunderbolt_duo/IPTS/IPTS_14832/Sebastien_raw_September_2015_time_dictionary.dat
