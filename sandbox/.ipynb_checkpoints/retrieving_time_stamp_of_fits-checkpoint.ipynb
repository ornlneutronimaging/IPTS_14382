# %%
import os
import pyfits
import glob
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Select working data set

# %%
root_folder = '/Volumes/My Book Thunderbolt Duo/IPTS/BraggEdge/SNAP/SNAP_August_September_2015/'

# %%
data_folder = 'September3_2015/'
data_dir = root_folder + data_folder

# %%
# list all *.fits file from data_dir
list_fname = glob.glob(data_dir + '/*.fits')

# %%
number_of_files = len(list_fname)
pprint("folder requested: %s" %data_dir)
pprint("Number of files: %d" %number_of_files)
# Out:
# ('folder requested: /Volumes/My Book Thunderbolt '
#  'Duo/IPTS/BraggEdge/SNAP/SNAP_August_September_2015/September3_2015/')
# 'Number of files: 123091'

# %% [markdown]
# ## Retrieving time stamp (when the file was created)

# %%
_file = list_fname[0]
hdu_list = pyfits.open(_file)
hdu = hdu_list[0]
_image = hdu.data

# %%
print(hdu_list.info())
# Out:
# Filename: /Volumes/My Book Thunderbolt Duo/IPTS/BraggEdge/SNAP/SNAP_August_September_2015/September3_2015/Image000_00000.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      34   (512, 512)   int16
# None

# %%
pprint(hdu.header)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                  512 / length of data axis 1
# NAXIS2  =                  512 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TOF     =             9.6E-007 / Ttime of flight from the external trigger
# TIMEBIN =           1.024E-005 / Time width of this image
# N_COUNTS=                10397 / Total counts in this image
# N_TRIGS =               215601 / Number of triggers acquired
# TEST1   = 'One_Continuous_Word_here' / Comment1
# TEST2   = '14.567  '           / Comment1
# TEST3   = '14.567  '           / Comment1
# TEST4   = '4.567   '           / Comment1
# TEST5   = '567     '           / 012345678 012345678 012345678 012345678 0123456
# TEST6   = '514.567 '           / Comment6
# TEST7   = '15567   '           / Comment7
# TEST8   = 'Hlkdh   '           / Comment8
# TEST9   = 'LKJ:lk  '           / Comment9
# TEST10  = 'JLKLILNNk'          / Comment10
# TEST11  = '464678  '           / Comment11
# TEST12  = '234239402398'       / Comment12
# TEST13  = '12sdkjfkj'          / Comment13
# TEST14  = '14.567  '           / Comment14
# TEST15  = '14.567  '           / Comment15
# TEST16  = '14.567  '           / Comment16
# TEST17  = '14.567  '           / Comment17
# TEST18  = '14.567  '           / Comment18
# TEST19  = '14.567  '           / Comment19
# TEST20  = '14.567  '           / Comment20
# TEST21  = '        '
# TEST22  = '14.567  '           / Comment2

# %%
# checking image
plt.figure()
plt.imshow(_image)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## using ctime

# %%
import time

# %%
print("last modified: %s" %time.ctime(os.path.getmtime(_file)))
# Out:
# last modified: Thu Sep  3 18:04:47 2015
